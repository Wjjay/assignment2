# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("co2_and_temperature.csv")
gdp = pd.read_csv("gdp_long.csv")
data.head()
# Out:
#    Year    Country Name  CO2 Emission Country Code Three_Letter_Country_Code  \
# 0  1960     Afghanistan      0.046057          AFG                       AFG
# 1  1960         Albania      1.258195          ALB                       ALB
# 2  1960         Algeria      0.557120          DZA                       DZA
# 3  1960  American Samoa           NaN          ASM                       ASM
# 4  1960         Andorra           NaN          AND                       AND
#
#   Continent_Name  Temperature Change
# 0           Asia                 NaN
# 1         Europe                 NaN
# 2         Africa                 NaN
# 3        Oceania                 NaN
# 4         Europe                 NaN

# %%
gdp.head()
# Out:
#   Country Code  Year           GDP
# 0          ABW  1960           NaN
# 1          AFE  1960  1.929193e+10
# 2          AFG  1960  5.377778e+08
# 3          AFW  1960  1.040732e+10
# 4          AGO  1960           NaN

# %%
gdp = gdp.drop(gdp[gdp.Year=="Unnamed: 65"].index)

# %%
gdp.Year = gdp.Year.astype(np.int64)

# %%
new_df = pd.merge(data, gdp, on=["Country Code", "Year"], how="left")

# %%
new_df.head()
# Out:
#    Year    Country Name  CO2 Emission Country Code Three_Letter_Country_Code  \
# 0  1960     Afghanistan      0.046057          AFG                       AFG
# 1  1960         Albania      1.258195          ALB                       ALB
# 2  1960         Algeria      0.557120          DZA                       DZA
# 3  1960  American Samoa           NaN          ASM                       ASM
# 4  1960         Andorra           NaN          AND                       AND
#
#   Continent_Name  Temperature Change           GDP
# 0           Asia                 NaN  5.377778e+08
# 1         Europe                 NaN           NaN
# 2         Africa                 NaN  2.723593e+09
# 3        Oceania                 NaN           NaN
# 4         Europe                 NaN           NaN

# %%
new_df.drop("Three_Letter_Country_Code", 1, inplace=True)

# %%
new_df.head()
# Out:
#    Year    Country Name  CO2 Emission Country Code Continent_Name  \
# 0  1960     Afghanistan      0.046057          AFG           Asia
# 1  1960         Albania      1.258195          ALB         Europe
# 2  1960         Algeria      0.557120          DZA         Africa
# 3  1960  American Samoa           NaN          ASM        Oceania
# 4  1960         Andorra           NaN          AND         Europe
#
#    Temperature Change           GDP
# 0                 NaN  5.377778e+08
# 1                 NaN           NaN
# 2                 NaN  2.723593e+09
# 3                 NaN           NaN
# 4                 NaN           NaN

# %%
new_df.to_csv("carbon_gdp_temp.csv",)

# %%
new
# Out:
#        Year           Country Name  CO2 Emission Country Code  \
# 0      1960            Afghanistan      0.046057          AFG
# 1      1960                Albania      1.258195          ALB
# 2      1960                Algeria      0.557120          DZA
# 3      1960         American Samoa           NaN          ASM
# 4      1960                Andorra           NaN          AND
# ...     ...                    ...           ...          ...
# 13537  2020  Virgin Islands (U.S.)           NaN          VIR
# 13538  2020     West Bank and Gaza           NaN          PSE
# 13539  2020            Yemen, Rep.           NaN          YEM
# 13540  2020                 Zambia           NaN          ZMB
# 13541  2020               Zimbabwe           NaN          ZWE
#
#       Three_Letter_Country_Code Continent_Name  Temperature Change
# 0                           AFG           Asia                 NaN
# 1                           ALB         Europe                 NaN
# ...

# %%
new.loc[new["Country Name"]=="United States"]
# Out:
#        Year   Country Name  CO2 Emission Country Code  \
# 211    1960  United States     15.999779          USA
# 433    1961  United States     15.681256          USA
# 655    1962  United States     16.013938          USA
# 877    1963  United States     16.482762          USA
# 1099   1964  United States     16.968119          USA
# ...     ...            ...           ...          ...
# 12643  2016  United States     15.131747          USA
# 12865  2017  United States     14.805882          USA
# 13087  2018  United States     15.240875          USA
# 13309  2019  United States           NaN          USA
# 13531  2020  United States           NaN          USA
#
#       Three_Letter_Country_Code Continent_Name  Temperature Change
# 211                         USA  North America                 NaN
# 433                         USA  North America               0.000
# 655                         USA  North America              -0.023
# ...

# %%
new.dropna()
# Out:
#        Year         Country Name  CO2 Emission Country Code  \
# 222    1961          Afghanistan      0.053589          AFG
# 223    1961              Albania      1.374186          ALB
# 224    1961              Algeria      0.535025          DZA
# 227    1961               Angola      0.082204          AGO
# 228    1961  Antigua and Barbuda      0.866667          ATG
# ...     ...                  ...           ...          ...
# 13088  2018              Uruguay      1.890244          URY
# 13089  2018           Uzbekistan      3.401191          UZB
# 13090  2018              Vanuatu      0.615017          VUT
# 13096  2018               Zambia      0.446065          ZMB
# 13097  2018             Zimbabwe      0.849793          ZWE
#
#       Three_Letter_Country_Code Continent_Name  Temperature Change
# 222                         AFG           Asia              -0.080
# 223                         ALB         Europe               0.631
# ...

# %%
new.loc[new["CO2 Emission"] == 0, "CO2 Emission"] = np.nan

# %%
new.to_csv("co2_and_temperature.csv", index=False)

# %%
new.loc[new["CO2 Emission"] >0]
# Out:
#        Year         Country Name  CO2 Emission Country Code  \
# 0      1960          Afghanistan      0.046057          AFG
# 1      1960              Albania      1.258195          ALB
# 2      1960              Algeria      0.557120          DZA
# 5      1960               Angola      0.100835          AGO
# 6      1960  Antigua and Barbuda      0.677418          ATG
# ...     ...                  ...           ...          ...
# 13091  2018        Venezuela, RB      4.782755          VEN
# 13092  2018              Vietnam      2.698806          VNM
# 13095  2018          Yemen, Rep.      0.326682          YEM
# 13096  2018               Zambia      0.446065          ZMB
# 13097  2018             Zimbabwe      0.849793          ZWE
#
#       Three_Letter_Country_Code Continent_Name  Temperature Change
# 0                           AFG           Asia                 NaN
# 1                           ALB         Europe                 NaN
# ...
